# %%
import requests
import sys

### Config Section

# Define the API endpoint URL

# SYNTH_URL = "http://prototype-aspire-dev.ncats.nih.gov/aicp-synthplanning/api/v1/prediction/top_yield_routes"
SYNTH_URL = "http://localhost:8002/aicp-synthplanning/api/v1/prediction/top_yield_routes"
BASE_URL = "http://localhost:5099/upload_json_to_ui/"

# Define the room ID
ROOM_ID = "fec4904d-76d3-420d-8d93-48cdc8451331"  # Replace with the actual room ID

# Specify whether to convert ASKCOS data
CONVERT_ASKCOS = False  # Set to True to convert ASKCOS data, False otherwise

INCHIKEY = "BACODVKOMBXPLL-UHFFFAOYSA-N"
RXN_STEPS = 3
QUERY_TYPE = "shortest_path"
LEAVES_AS_SM = True
TOP_N = 5
INCLUDE_RCS = False
BACKEND = "memgraph"
ANNOTATE_REACTIONS = True

JSON_FILE_PATH = "saved_json_example.json"







def fetch_route (url):
    headers = {"accept": "application/json", "Content-Type": "application/json"}

    payload = {
        "target_molecule_inchikey": INCHIKEY,
        "reaction_steps": RXN_STEPS, 
        "query_type": QUERY_TYPE,
        "leaves_as_sm": LEAVES_AS_SM,
        "top_n_routes": TOP_N,
        "include_route_candidates": INCLUDE_RCS,
        "graph_backend": BACKEND,
        "annotate_reactions": ANNOTATE_REACTIONS
    }
    
    try:
        response = requests.post(url, headers=headers, json=payload, verify=False)
        #print (response.json())
        #route = response.json()
    except:
        print ('[*] ERROR in fetching synthesis route. Terminating...')
        sys.exit(-1)

    #return (route)
    return (response)


def save_json_to_disk(route_response):
    """Save JSON to disk by calling the specified endpoint."""

    if route_response.status_code == 200:
        #print (route_response.json())
        route = route_response.json()
        with open(JSON_FILE_PATH, "w") as file:
            file.write(route_response.text)
        print("JSON saved to disk successfully!")
    else:
        print(f"Failed to save JSON. Status code: {response.status_code}, Response: {response.text}")







def upload_route_to_visualizer ():
    

    # Construct the URL with the room ID and convert_askcos as query parameters
    url = f"{BASE_URL}?room_id={ROOM_ID}&convert_askcos={str(CONVERT_ASKCOS).lower()}"

    # Open the JSON file
    files = {"file": open(JSON_FILE_PATH, "rb")}

    # Send the request to the API
    response = requests.post(url, files=files, verify=False)

    #response = requests.post(url, data=route, verify=False)

    # Close the file
    files["file"].close()

    # Check the response
    if response.status_code == 200:
        data = response.json()
        print("Upload successful!")
        #print("Response data:", data)
    else:
        print("Failed to upload JSON.")
        print("Status code:", response.status_code)
        print("Response:", response.text)



# route_res = fetch_route (SYNTH_URL) 

# save_json_to_disk(route_res)

upload_route_to_visualizer()
# Out:
# Upload successful!
